# %% [markdown]
# <a href="https://colab.research.google.com/github/didi-a-p/BootcampDataScienceAlura/blob/main/Analisando%20dados%20da%20sa%C3%BAde%20com%20Python%20e%20Pandas/Desafios%20em%20notebooks%20separados/Desafios_Aula_1_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preparando o Ambiente

# %%
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.ticker as ticker

# %%
url = "https://raw.githubusercontent.com/didi-a-p/BootcampDataScienceAlura/main/Analisando%20dados%20da%20sa%C3%BAde%20com%20Python%20e%20Pandas/dados/A151346189_28_143_208.csv"

# %%
# dados = pd.read_csv(url, sep=";", skiprows=2, skipfooter=12, encoding="cp1252", engine='python')

# %%
dados = pd.read_csv(url, sep=";", skiprows=3, skipfooter=12, encoding="ISO-8859-1",engine='python',thousands='.', decimal=',')

# %%
pd.options.display.float_format = "{:.2f}".format

# %% [markdown]
# # Escolher um titulo mais descritivo, que passe a mensagem adequada.

# %%
ax =  dados.plot(x='Unidade da Federação', y='2008/Ago', kind='bar', figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}")) #"{:.2f}"
plt.title("Valor de Procedimentos Hospitalares do SUS por UF em Agosto de 2008")
plt.show()

# %% [markdown]
# # Faça a mesma analize para o mes mais recente.

# %%
dados[dados.columns[-3]]
# Out:
# 0     11152107.08
# 1      3915193.20
# 2     19346450.18
# 3      3015488.30
# 4     38438873.79
# 5      3249565.87
# 6      9131707.60
# 7     32936503.37
# 8     17871598.61
# 9     55180751.48
# 10    26302373.94
# 11    26902438.72
# 12    74192800.58
# 13    18351680.84
# 14    10313262.56
# 15    83992134.91
# 16   164891823.64
# 17    33290880.33
# 18    98722687.54
# 19   366721243.71
# 20   109658360.43
# 21    63467828.84
# 22   100531035.83
# 23    18755557.92
# 24    16371639.49
# 25    39405050.36
# 26    25269773.34
# Name: 2020/Jul, dtype: float64

# %%
dados.columns[-3]
# Out:
# '2020/Jul'

# %%
dados['2020/Jul'].describe()
# Out:
# count          27.00
# mean     54495511.57
# std      73974287.16
# min       3015488.30
# 25%      17121619.05
# 50%      26902438.72
# 75%      68830314.71
# max     366721243.71
# Name: 2020/Jul, dtype: float64

# %%
dados['2020/Jul'].mean()
# Out:
# 54495511.57259259

# %%
ax =  dados.plot(x='Unidade da Federação', y='2020/Jul', kind='bar', figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}")) #"{:.2f}"
plt.title("Valor de Procedimentos Hospitalares do SUS por UF em Julho de 2020")
plt.show()

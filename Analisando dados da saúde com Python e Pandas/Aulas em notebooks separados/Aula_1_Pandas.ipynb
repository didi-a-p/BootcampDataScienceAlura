# %% [markdown]
# <a href="https://colab.research.google.com/github/didi-a-p/BootcampDataScienceAlura/blob/main/Analisando%20dados%20da%20sa%C3%BAde%20com%20Python%20e%20Pandas/Aulas%20em%20notebooks%20separados/Aula_1_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Preparando o Ambiente

# %%
import pandas as pd

# %%
url = "https://raw.githubusercontent.com/didi-a-p/BootcampDataScienceAlura/main/Analisando%20dados%20da%20sa%C3%BAde%20com%20Python%20e%20Pandas/dados/A151346189_28_143_208.csv"

# %%
# dados = pd.read_csv(url, sep=";", skiprows=3, skipfooter=12, encoding="cp1252", engine='python',thousands='.', decimal=',')

# %%
dados = pd.read_csv(url, sep=";", skiprows=3, skipfooter=12, encoding="ISO-8859-1",engine='python',thousands='.', decimal=',')

# %% [markdown]
# # Explorando

# %%
dados.head()
# Out:
#   Unidade da Federação     2008/Jan  ...     2020/Ago         Total
# 0          11 Rondônia   1388528.39  ...  10285455.78  9.291297e+08
# 1              12 Acre    902416.00  ...            -  4.206680e+08
# 2          13 Amazonas   4735529.42  ...  14726443.67  1.771655e+09
# 3           14 Roraima    657889.53  ...   2826486.18  3.050109e+08
# 4              15 Pará  18864744.11  ...  39911193.02  4.437116e+09
#
# [5 rows x 154 columns]

# %%
dados.tail()
# Out:
#      Unidade da Federação     2008/Jan  ...      2020/Ago         Total
# 22   43 Rio Grande do Sul  30931325.46  ...  101374341.51  1.195865e+10
# 23  50 Mato Grosso do Sul   5377392.11  ...   19241624.02  2.172158e+09
# 24         51 Mato Grosso   4795299.01  ...   17790649.87  2.036924e+09
# 25               52 Goiás  15310637.29  ...   43984702.05  4.657350e+09
# 26    53 Distrito Federal   4745919.19  ...   26526196.39  2.429933e+09
#
# [5 rows x 154 columns]

# %%
dados.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 27 entries, 0 to 26
# Columns: 154 entries, Unidade da Federação to Total
# dtypes: float64(151), object(3)
# memory usage: 32.6+ KB

# %%
dados.mean()
# Out:
# 2008/Jan    1.512685e+07
# 2008/Fev    2.271016e+07
# 2008/Mar    2.459419e+07
# 2008/Abr    2.543196e+07
# 2008/Mai    2.651125e+07
#                 ...
# 2020/Abr    4.101366e+07
# 2020/Mai    4.419363e+07
# 2020/Jun    4.732999e+07
# 2020/Jul    5.449551e+07
# Total       5.993732e+09
# Length: 151, dtype: float64

# %%
pd.options.display.float_format = "{:.2f}".format

# %%
dados.mean()
# Out:
# 2008/Jan     15126846.64
# 2008/Fev     22710158.12
# 2008/Mar     24594187.35
# 2008/Abr     25431957.83
# 2008/Mai     26511245.91
#                 ...
# 2020/Abr     41013660.39
# 2020/Mai     44193633.75
# 2020/Jun     47329994.46
# 2020/Jul     54495511.57
# Total      5993731798.30
# Length: 151, dtype: float64

# %%
dados.columns[1]
# Out:
# '2008/Jan'

# %%
dados['2008/Jan'].describe()
# Out:
# count         27.00
# mean    15126846.64
# std     19159188.30
# min       657889.53
# 25%      4740724.30
# 50%      7985142.43
# 75%     17684828.78
# max     91678473.48
# Name: 2008/Jan, dtype: float64

# %%
dados['2008/Ago'].mean()
# Out:
# 27800320.306666665

# %%
dados.plot(x='Unidade da Federação', y='2008/Ago', kind='bar', figsize=(9,6))

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

import matplotlib.ticker as ticker

# %%
ax =  dados.plot(x='Unidade da Federação', y='2008/Ago', kind='bar', figsize=(9,6))
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}")) #"{:.2f}"
plt.title("Valor por unidade da Federação")
plt.show()

# %% [markdown]
# # Escolher um titulo mais descritivo, que passe a mensagem adequada.

# %% [markdown]
# # Faça a mesma analize para o mes mais recente.

# %%
dados[['2008/Ago', '2008/Set']].head()
# Out:
#      2008/Ago    2008/Set
# 0  3231494.61  3117178.63
# 1  2089107.14  2275708.53
# 2  9352532.70  9363099.35
# 3   894271.18   910424.17
# 4 23341218.03 25172261.32

# %%
colunas_usaveis = dados.mean().index.tolist()
colunas_usaveis.insert(0, "Unidade da Federação")
colunas_usaveis
# Out:
# ['Unidade da Federação',
#  '2008/Jan',
#  '2008/Fev',
#  '2008/Mar',
#  '2008/Abr',
#  '2008/Mai',
#  '2008/Jun',
#  '2008/Jul',
#  '2008/Ago',
#  '2008/Set',
#  '2008/Out',
#  '2008/Nov',
#  '2008/Dez',
#  '2009/Jan',
#  '2009/Fev',
#  '2009/Mar',
#  '2009/Abr',
#  '2009/Mai',
#  '2009/Jun',
#  '2009/Jul',
#  '2009/Ago',
#  '2009/Out',
#  '2009/Nov',
#  '2009/Dez',
#  '2010/Jan',
#  '2010/Fev',
#  '2010/Mar',
#  '2010/Abr',
#  '2010/Mai',
#  '2010/Jun',
#  '2010/Jul',
#  '2010/Ago',
#  '2010/Set',
#  '2010/Out',
#  '2010/Nov',
#  '2010/Dez',
#  '2011/Jan',
#  '2011/Fev',
#  '2011/Mar',
#  '2011/Abr',
#  '2011/Mai',
#  '2011/Jun',
#  '2011/Jul',
#  '2011/Ago',
#  '2011/Set',
#  '2011/Out',
#  '2011/Nov',
#  '2011/Dez',
#  '2012/Jan',
#  '2012/Fev',
#  '2012/Mar',
#  '2012/Abr',
#  '2012/Mai',
#  '2012/Jun',
#  '2012/Jul',
#  '2012/Ago',
#  '2012/Set',
#  '2012/Out',
#  '2012/Nov',
#  '2012/Dez',
#  '2013/Jan',
#  '2013/Fev',
#  '2013/Mar',
#  '2013/Abr',
#  '2013/Mai',
#  '2013/Jun',
#  '2013/Jul',
#  '2013/Ago',
#  '2013/Set',
#  '2013/Out',
#  '2013/Nov',
#  '2013/Dez',
#  '2014/Jan',
#  '2014/Fev',
#  '2014/Mar',
#  '2014/Abr',
#  '2014/Mai',
#  '2014/Jun',
#  '2014/Jul',
#  '2014/Ago',
#  '2014/Set',
#  '2014/Out',
#  '2014/Nov',
#  '2014/Dez',
#  '2015/Jan',
#  '2015/Fev',
#  '2015/Mar',
#  '2015/Abr',
#  '2015/Mai',
#  '2015/Jun',
#  '2015/Jul',
#  '2015/Ago',
#  '2015/Set',
#  '2015/Out',
#  '2015/Nov',
#  '2015/Dez',
#  '2016/Jan',
#  '2016/Fev',
#  '2016/Mar',
#  '2016/Abr',
#  '2016/Mai',
#  '2016/Jun',
#  '2016/Jul',
#  '2016/Ago',
#  '2016/Set',
#  '2016/Out',
#  '2016/Nov',
#  '2016/Dez',
#  '2017/Jan',
#  '2017/Fev',
#  '2017/Mar',
#  '2017/Abr',
#  '2017/Mai',
#  '2017/Jun',
#  '2017/Jul',
#  '2017/Ago',
#  '2017/Set',
#  '2017/Out',
#  '2017/Nov',
#  '2017/Dez',
#  '2018/Jan',
#  '2018/Fev',
#  '2018/Mar',
#  '2018/Abr',
#  '2018/Mai',
#  '2018/Jun',
#  '2018/Jul',
#  '2018/Ago',
#  '2018/Set',
#  '2018/Out',
#  '2018/Nov',
#  '2018/Dez',
#  '2019/Jan',
#  '2019/Fev',
#  '2019/Mar',
#  '2019/Abr',
#  '2019/Mai',
#  '2019/Jun',
#  '2019/Jul',
#  '2019/Ago',
#  '2019/Set',
#  '2019/Out',
#  '2019/Nov',
#  '2019/Dez',
#  '2020/Jan',
#  '2020/Fev',
#  '2020/Mar',
#  '2020/Abr',
#  '2020/Mai',
#  '2020/Jun',
#  '2020/Jul',
#  'Total']

# %%
usaveis = dados[colunas_usaveis]
usaveis.head()
# Out:
#   Unidade da Federação    2008/Jan  ...    2020/Jul         Total
# 0          11 Rondônia  1388528.39  ... 11152107.08  929129659.72
# 1              12 Acre   902416.00  ...  3915193.20  420668039.63
# 2          13 Amazonas  4735529.42  ... 19346450.18 1771654871.23
# 3           14 Roraima   657889.53  ...  3015488.30  305010883.18
# 4              15 Pará 18864744.11  ... 38438873.79 4437115730.71
#
# [5 rows x 152 columns]

# %%
usaveis = usaveis.set_index("Unidade da Federação")
usaveis
# Out:
#                           2008/Jan     2008/Fev  ...     2020/Jul          Total
# Unidade da Federação                             ...
# 11 Rondônia             1388528.39   2931283.42  ...  11152107.08   929129659.72
# 12 Acre                  902416.00   1497206.26  ...   3915193.20   420668039.63
# 13 Amazonas             4735529.42   7118990.57  ...  19346450.18  1771654871.23
# 14 Roraima               657889.53    777939.31  ...   3015488.30   305010883.18
# 15 Pará                18864744.11  19553758.20  ...  38438873.79  4437115730.71
# 16 Amapá                1120973.34   1268740.33  ...   3249565.87   291637984.75
# 17 Tocantins            3441592.69   4985688.85  ...   9131707.60   999998621.85
# 21 Maranhão            10723506.39  13559679.41  ...  32936503.37  3632860959.84
# 22 Piauí                7985142.43  10079928.25  ...  17871598.61  2130616492.35
# 23 Ceará               15539821.90  25735101.55  ...  55180751.48  6197357245.98
# 24 Rio Grande do Norte  5947814.08   9509755.83  ...  26302373.94  2477372149.60
# 25 Paraíba             10723002.45  11386274.47  ...  26902438.72  2470550104.25
# 26 Pernambuco          14393949.89  24181400.95  ...  74192800.58  8046954289.39
# 27 Alagoas              6243726.32   8376622.16  ...  18351680.84  2104405303.11
# 28 Sergipe              2780750.11   3676483.16  ...  10313262.56  1130337049.71
# 29 Bahia               21211522.47  28189304.95  ...  83992134.91  9193802684.16
# 31 Minas Gerais        45671659.76  70194037.10  ... 164891823.64 19160106499.88
# 32 Espírito Santo       5456723.98   9102212.86  ...  33290880.33  3139189177.73
# 33 Rio de Janeiro      23025258.52  28394310.93  ...  98722687.54  9696364115.11
# 35 São Paulo           91678473.48 148677526.82  ... 366721243.71 38929549655.89
# 41 Paraná              38266347.46  55384670.52  ... 109658360.43 13786964617.27
# 42 Santa Catarina      16504913.45  25651429.11  ...  63467828.84  7324100054.96
# 43 Rio Grande do Sul   30931325.46  57363420.01  ... 100531035.83 11958647088.33
# 50 Mato Grosso do Sul   5377392.11   7002472.61  ...  18755557.92  2172157981.36
# 51 Mato Grosso          4795299.01   8684882.23  ...  16371639.49  2036923784.59
# 52 Goiás               15310637.29  22258668.68  ...  39405050.36  4657350310.70
# 53 Distrito Federal     4745919.19   7632480.67  ...  25269773.34  2429933198.76
#
# [27 rows x 151 columns]

# %%
usaveis['2019/Ago'].head()
# Out:
# Unidade da Federação
# 11 Rondônia    9170787.53
# 12 Acre        3204998.88
# 13 Amazonas   15787896.78
# 14 Roraima     3788154.80
# 15 Pará       31179893.86
# Name: 2019/Ago, dtype: float64

# %%
usaveis.loc["12 Acre"]
# Out:
# 2008/Jan      902416.00
# 2008/Fev     1497206.26
# 2008/Mar     1794028.48
# 2008/Abr     1730469.42
# 2008/Mai     1819443.92
#                ...
# 2020/Abr     2286642.60
# 2020/Mai     2896340.24
# 2020/Jun     3045245.80
# 2020/Jul     3915193.20
# Total      420668039.63
# Name: 12 Acre, Length: 151, dtype: float64

# %%
usaveis.T.plot(figsize=(12,6))

# %%
usaveis = usaveis.drop("Total", axis=1)
usaveis
# Out:
#                           2008/Jan     2008/Fev  ...     2020/Jun     2020/Jul
# Unidade da Federação                             ...
# 11 Rondônia             1388528.39   2931283.42  ...   8725530.68  11152107.08
# 12 Acre                  902416.00   1497206.26  ...   3045245.80   3915193.20
# 13 Amazonas             4735529.42   7118990.57  ...  20897542.93  19346450.18
# 14 Roraima               657889.53    777939.31  ...   3401864.29   3015488.30
# 15 Pará                18864744.11  19553758.20  ...  41625331.28  38438873.79
# 16 Amapá                1120973.34   1268740.33  ...   2009912.57   3249565.87
# 17 Tocantins            3441592.69   4985688.85  ...   7384806.71   9131707.60
# 21 Maranhão            10723506.39  13559679.41  ...  33099356.79  32936503.37
# 22 Piauí                7985142.43  10079928.25  ...  14547134.38  17871598.61
# 23 Ceará               15539821.90  25735101.55  ...  54409441.05  55180751.48
# 24 Rio Grande do Norte  5947814.08   9509755.83  ...  21466739.79  26302373.94
# 25 Paraíba             10723002.45  11386274.47  ...  17332974.95  26902438.72
# 26 Pernambuco          14393949.89  24181400.95  ...  63987469.53  74192800.58
# 27 Alagoas              6243726.32   8376622.16  ...  15401094.32  18351680.84
# 28 Sergipe              2780750.11   3676483.16  ...   8057935.10  10313262.56
# 29 Bahia               21211522.47  28189304.95  ...  69567655.48  83992134.91
# 31 Minas Gerais        45671659.76  70194037.10  ... 139699763.30 164891823.64
# 32 Espírito Santo       5456723.98   9102212.86  ...  28942645.28  33290880.33
# 33 Rio de Janeiro      23025258.52  28394310.93  ...  91507444.94  98722687.54
# 35 São Paulo           91678473.48 148677526.82  ... 306425499.30 366721243.71
# 41 Paraná              38266347.46  55384670.52  ...  96977288.37 109658360.43
# 42 Santa Catarina      16504913.45  25651429.11  ...  54457911.56  63467828.84
# 43 Rio Grande do Sul   30931325.46  57363420.01  ...  86051002.13 100531035.83
# 50 Mato Grosso do Sul   5377392.11   7002472.61  ...  17331445.92  18755557.92
# 51 Mato Grosso          4795299.01   8684882.23  ...  13151005.63  16371639.49
# 52 Goiás               15310637.29  22258668.68  ...  35701473.15  39405050.36
# 53 Distrito Federal     4745919.19   7632480.67  ...  22704335.27  25269773.34
#
# [27 rows x 150 columns]

# %%
usaveis.T.plot(figsize=(12,6))

# %%
ax = usaveis.T.plot(figsize=(12,7))
plt.legend(bbox_to_anchor=(1, 1.02), loc='upper left')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}")) #"{:.2f}"
plt.title("Evolução dos valores de Procedimentos Hospitalares do SUS por local de internação")
plt.show()

# %%
usaveis[18:23].T
# Out:
# Unidade da Federação  33 Rio de Janeiro  ...  43 Rio Grande do Sul
# 2008/Jan                    23025258.52  ...           30931325.46
# 2008/Fev                    28394310.93  ...           57363420.01
# 2008/Mar                    44567062.94  ...           51547794.07
# 2008/Abr                    44054604.82  ...           56673338.49
# 2008/Mai                    44911021.15  ...           48397733.07
# ...                                 ...  ...                   ...
# 2020/Mar                    77004637.47  ...          102876132.83
# 2020/Abr                    71403516.21  ...           83000318.02
# 2020/Mai                    85094073.33  ...           82381774.95
# 2020/Jun                    91507444.94  ...           86051002.13
# 2020/Jul                    98722687.54  ...          100531035.83
#
# [150 rows x 5 columns]

# %%
ax = usaveis[18:23].T.plot(figsize=(12,7))
plt.legend(bbox_to_anchor=(1, 1.02), loc='upper left')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}")) #"{:.2f}"
plt.title("Evolução dos valores de Procedimentos Hospitalares do SUS por local de internação")
plt.show()

# %%
# https://matplotlib.org/stable/tutorials/colors/colormaps.html  paleta de cores

ax = usaveis.T.plot(figsize=(12,7), cmap = 'gist_ncar',)
plt.legend(bbox_to_anchor=(1, 1.02), loc='upper left')
ax.yaxis.set_major_formatter(ticker.StrMethodFormatter("{x:,.2f}")) #"{:.2f}"
plt.title("Evolução dos valores de Procedimentos Hospitalares do SUS por local de internação")
plt.show()

# %%
usaveis[:5].T.plot(figsize=(12,7))

# %%
usaveis.sample(5).T.plot(figsize=(12,7))

# %%
import numpy as np
np.random.seed(687942)

usaveis.sample(n=7)
# Out:
#                           2008/Jan    2008/Fev  ...     2020/Jun     2020/Jul
# Unidade da Federação                            ...
# 32 Espírito Santo       5456723.98  9102212.86  ...  28942645.28  33290880.33
# 31 Minas Gerais        45671659.76 70194037.10  ... 139699763.30 164891823.64
# 24 Rio Grande do Norte  5947814.08  9509755.83  ...  21466739.79  26302373.94
# 17 Tocantins            3441592.69  4985688.85  ...   7384806.71   9131707.60
# 53 Distrito Federal     4745919.19  7632480.67  ...  22704335.27  25269773.34
# 50 Mato Grosso do Sul   5377392.11  7002472.61  ...  17331445.92  18755557.92
# 16 Amapá                1120973.34  1268740.33  ...   2009912.57   3249565.87
#
# [7 rows x 150 columns]

# %%
usaveis.sample(n=7)
# Out:
#                         2008/Jan     2008/Fev  ...     2020/Jun     2020/Jul
# Unidade da Federação                           ...
# 42 Santa Catarina    16504913.45  25651429.11  ...  54457911.56  63467828.84
# 33 Rio de Janeiro    23025258.52  28394310.93  ...  91507444.94  98722687.54
# 31 Minas Gerais      45671659.76  70194037.10  ... 139699763.30 164891823.64
# 35 São Paulo         91678473.48 148677526.82  ... 306425499.30 366721243.71
# 21 Maranhão          10723506.39  13559679.41  ...  33099356.79  32936503.37
# 52 Goiás             15310637.29  22258668.68  ...  35701473.15  39405050.36
# 32 Espírito Santo     5456723.98   9102212.86  ...  28942645.28  33290880.33
#
# [7 rows x 150 columns]

# %%
usaveis['Total'] = usaveis.sum(axis=1)
usaveis.head()
# Out:
#                         2008/Jan    2008/Fev  ...    2020/Jul         Total
# Unidade da Federação                          ...
# 11 Rondônia           1388528.39  2931283.42  ... 11152107.08  915239196.51
# 12 Acre                902416.00  1497206.26  ...  3915193.20  420668039.63
# 13 Amazonas           4735529.42  7118990.57  ... 19346450.18 1747197793.40
# 14 Roraima             657889.53   777939.31  ...  3015488.30  300482785.75
# 15 Pará              18864744.11 19553758.20  ... 38438873.79 4369236568.47
#
# [5 rows x 151 columns]
